# %% [markdown]
# <a href="https://colab.research.google.com/github/Thinh1135/AI/blob/main/18_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
y_test.shape
# Out:
# (10000,)

# %%
class_name=['T-shirt/Top','Trousers','Pullover','Press','Coat','Sandal','Shirt','Sneaker','Bag','Ankel Boat']

# %%
import matplotlib.pyplot as plt 
plt.imshow(x_train[1101])
plt.show()
print(class_name[y_train[1101]])
# Out:
# Shirt

# %%
from keras.layers.serialization import activation
from keras import models

from keras import layers
model=models.Sequential()
model.add(layers.Dense(512, activation= 'relu', input_shape=(28*28,)))
model.add(layers.Dense(10,activation='softmax'))
model.summary()

x_train=x_train.reshape((60000,28*28))
x_train=x_train.astype('float32')/255
x_test=x_test.reshape((10000,28*28))
x_test=x_test.astype('float32')/255

x_test.shape
x_train.shape
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# (60000, 784)

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
y_train.shape
y_test.shape
# Out:
# (10000, 10)

# %%
from keras.metrics import metrics
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs = 100, batch_size = 128)
# Out:
# Epoch 1/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.5540 - accuracy: 0.8023
# Epoch 2/100
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3812 - accuracy: 0.8613
# Epoch 3/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3378 - accuracy: 0.8754
# Epoch 4/100
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3095 - accuracy: 0.8867
# Epoch 5/100
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2898 - accuracy: 0.8931
# Epoch 6/100
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2764 - accuracy: 0.8971
# Epoch 7/100
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2635 - accuracy: 0.9028
# Epoch 8/100
# 469/469 [==============================] - 5s 12ms/step - loss: 0.2530 - accuracy: 0.9066
# Epoch 9/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2429 - accuracy: 0.9101
# Epoch 10/100
# ...

# %%
from keras.utils import load_img
import numpy as np
url='22.jpg'
img=load_img(url,target_size = (784,784))
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,784,784,3)
img=img.astype('float32')
img=img/255
