# %% [markdown]
# <a href="https://colab.research.google.com/github/Thinh1135/AI/blob/main/Bu%E1%BB%95i_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(6)
y=x+1
plt.plot(x,y,'o--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(6)
y=x+1
plt.plot(x,-y,'o-')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(6)
y=x+1
plt.title('y=x & y=-x')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(6)
y=x+1
plt.ylabel('y')
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-7a8ee26adb50> in <module>
#       4 y=x+1
#       5 plt.ylabel('y')
# ----> 6 ply.show
#
# NameError: name 'ply' is not defined

# %%
plt.plot(x)
plt.show()

# %%
x=np.arange(6)
y=x+1
plt.xlabel('x')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=[4,5,3,1,6,7]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(70)
plt.plot(x,x**3+1)
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2)

plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**3)
plt.plot(x,-2*x)
plt.plot(x,-2**x)
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2,'--',x,-x**3,'.',x,-2*x,'-',x,-2**x,':',)
plt.show()

# %%
x=np.arange(9)
plt.subplots_adjust(wspace=0.3,hspace=0.3)
plt.subplot(2,2,1)
plt.plot(x,-x**2,color='g')
plt.subplot(2,2,2)
plt.plot(x,-x**3,color='r')
plt.subplot(2,2,3)
plt.plot(x,-2*x,color='y')
plt.subplot(2,2,4)
plt.plot(x,-2**x,'.')
plt.show()

# %%
plt.axis([0,200,0,60])
plt.scatter(60,50,s=1000,color='g',alpha=1)
plt.scatter(80,50,s=1000,color='g',alpha=.5)
plt.scatter(100,50,s=1000,color='g',alpha=.1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot([1,2],[4,3],linewidth=5,color='g')
plt.text(1,3.7,'con cu bu')
# Out:
# Text(1, 3.7, 'con cu bu')

# %%
plt.arrow(1,2,0.5,0.2,head_length=1,head_width=2,color='g')

# %%
x=np.arange(4)
y=np.random.rand(4)
plt.bar(x,y)
plt.show()

# %%
y=np.random.rand(3,4)
plt.bar(x+0,y[0],color='g',width=0.25)
plt.bar(x+0.25,y[1],color='b',width=0.25)
plt.bar(x+0.5,y[2],color='y',width=0.25)
plt.show()

# %%
N=1000
x=np.random.rand(N)
y=np.random.rand(N)
colors=np.random.rand(N)
size=1000
plt.scatter(x,y,s=size,c=color,alpha=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-b0e93c7ff66d> in <module>
#       4 colors=np.random.rand(N)
#       5 size=1000
# ----> 6 plt.scatter(x,y,s=size,c=color,alpha=1)
#       7 plt.show()
#
# NameError: name 'color' is not defined
